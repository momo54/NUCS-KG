# %%
from rdflib import Graph

# Create an RDFLib graph
g = Graph()

# Load the Turtle file into the graph
g.parse("XP/all.ttl", format="turtle")

# Print the number of triples in the graph
print(f"Graph has {len(g)} triples.")
# Out:
# Graph has 5649 triples.

# %%
# Define the SPARQL query to display parcours_code by parcours_level
query_parcours = """
PREFIX ex: <http://example.org/course/>
SELECT ?level ?code
WHERE {
    # ?ue ex:parcours_level ?level ;
        ex:parcours_code ?code .
}
GROUP BY ?level ?code
ORDER BY ?level 
"""

# Execute the query
results_parcours = g.query(query_parcours)

# Print the results
print(f"Number of results: {len(results_parcours)}")
for row in results_parcours:
    print(f"Level: {row.level}, Code: {row.code}")
# Out:
# Number of results: 27
# Level: L1, Code: INFO
# Level: L1, Code: INFOMATH
# Level: L1, Code: INFOMATHPA
# Level: L1, Code: INFOPA
# Level: L2, Code: CMI
# Level: L2, Code: INFO
# Level: L2, Code: INFOLAAS
# Level: L2, Code: INFOMATH
# Level: L3, Code: CMI
# Level: L3, Code: INFO
# Level: L3, Code: INFOLAAS
# Level: L3, Code: INFOMATH
# Level: L3, Code: MIAGE
# Level: L3, Code: MIAGEALTERNANCE
# Level: M1, Code: DS
# Level: M1, Code: VICO
# Level: M1, Code: CMI
# Level: M1, Code: ATAL
# Level: M1, Code: ALMA
# Level: M1, Code: CMD
# Level: M1, Code: ORO
# Level: M2, Code: DS
# Level: M2, Code: VICO
# Level: M2, Code: CMI
# Level: M2, Code: ATAL
# Level: M2, Code: ALMA
# Level: M2, Code: ORO

# %%
# Define the SPARQL query to count distinct UEs
query_distinct_ue = """
PREFIX ex: <http://example.org/course/>
SELECT (COUNT(DISTINCT ?ue) AS ?distinctUEs)
WHERE {
    # ?ue a ex:UE .
}
"""

# Execute the query
results_distinct_ue = g.query(query_distinct_ue)

# Print the result
for row in results_distinct_ue:
    print(f"Number of distinct UEs: {row.distinctUEs}")
# Out:
# Number of distinct UEs: 247

# %%
# Define the SPARQL query to select UE from L1 Info
query = """
PREFIX ex: <http://example.org/course/>
SELECT *
WHERE {
#    ?ue ex:parcours_level ?level ;
#        ex:parcours_code ?code ;
    {
    # ?ue a ex:UE .
    # ?ue ex:parcours_level "L1" ;
        ex:parcours_code "INFO" .
    } Union {
    # ?ue a ex:UE .
    # ?ue ex:parcours_level "L2" ;
        ex:parcours_code "INFO" ;
    } union {
    # ?ue a ex:UE .
    # ?ue ex:parcours_level "L3" ;
        ex:parcours_code "INFO" .
    } union {
    # ?ue a ex:UE .
    # ?ue ex:parcours_level "M1" ;
        ex:parcours_code "ALMA" .
    } union {
    # ?ue a ex:UE .
    # ?ue ex:parcours_level "M2" ;
        ex:parcours_code "ALMA" .
    } 
}
"""

# Execute the query
results = g.query(query)

# Print the results
print(f"Number of results: {len(results)}")
for row in results:
    print(f"{row}")
# Out:
# Number of results: 124
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1AE051'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1AE052'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1AE053'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1AE054'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1AU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1MU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1PU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1PU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1TU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG1TU060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2AE051'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2AE052'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2AE053'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2AE054'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2AU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2HU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2HU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2HU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2HU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IE011'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IE012'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2IU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2MU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2TU060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG2TU090'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3AU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3IU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3IU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3IU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3MU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3TU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3TU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3TU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG3TU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4AU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4IU070'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4MU060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE011'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE012'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE101'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE102'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE103'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE104'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE105'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE106'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE107'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE108'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE109'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE110'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE111'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE112'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE113'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE114'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TE115'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG4TU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31A060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31I010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31I020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31I030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31I040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31I050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X31T060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32A060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32I010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32I020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32I030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32I040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32I050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_X32T060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG5TU200'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XLG6TU200'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1AU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE071'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE072'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE301'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE302'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE312'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IE313'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU070'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU080'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU300'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU310'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS1IU320'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2AU000'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IE011'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IE012'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU070'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU080'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU090'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU100'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU110'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU120'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU130'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU310'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS2IU320'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU010'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU020'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU030'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU040'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU050'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU060'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU070'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU080'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU090'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS3IU100'),)
# (rdflib.term.URIRef('http://example.org/course/UE_XMS4IU010'),)

# %%
##
## Be careful to not have several objectives, label or contetnt for the same UE
##

query_ue = """
PREFIX course: <http://example.org/course/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?s (COUNT(DISTINCT ?label) AS ?labelCount) (COUNT(DISTINCT ?content) AS ?contentCount) (COUNT(DISTINCT ?objective) AS ?objectiveCount)
WHERE {
    # ?s course:content ?content .
    # ?s rdfs:label ?label .
    # ?s course:objective ?objective .
} group by ?s 
"""

# Execute the query
results_ue = g.query(query_ue)

# Print the results
print(f"Number of results: {len(results_ue)}")
for row in results_ue:
    print(f"Subject: {row.s}, Label Count: {row.labelCount}, Content Count: {row.contentCount}, Objective Count: {row.objectiveCount}")
# Out:
# Number of results: 209
# Subject: http://example.org/course/UE_Inconnu, Label Count: 4, Content Count: 4, Objective Count: 4
# Subject: http://example.org/course/UE_X31A060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31CI10, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_X32T060, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG1AU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG1IU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG1IU040, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG1TU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2AU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2IU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2IU020, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2IU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2IU040, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2IU060, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG2TU060, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG3AU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG3TU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG3TU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG3TU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4AU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TU020, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TU040, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5AU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5AU210, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IE120, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU020, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU070, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU110, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU220, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU230, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU270, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5TU200, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6AU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6AU210, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IE010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU020, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU080, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU110, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU120, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU130, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU210, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU220, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU230, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU300, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU310, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6TU200, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1AU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1HMIU1, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1HMIU2, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU060, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU080, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU230, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU320, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1TU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2HMIU1, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2HMIU2, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU020, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU050, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU060, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU080, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU090, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU110, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU130, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU200, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU310, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU320, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU010, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU020, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU030, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU040, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU050, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU060, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU070, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU100, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU260, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU270, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU310, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU350, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU400, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU410, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3WU370, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3WU390, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS4IU010, Label Count: 1, Content Count: 1, Objective Count: 2
# Subject: http://example.org/course/UE_XMS4IU200, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS4IU400, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_X31I010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31I020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31I030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31I040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31I050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31M060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31M070, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X31T060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32A060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32CI10, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_X32I010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32I020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3MU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4MU050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4MU060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS2IU070, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_X32I030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32I040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32I050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32I130, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_X32M060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_X32M070, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG1MU010, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG1MU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG1PU020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG1PU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG1TU060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2HU070, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2MU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2MU050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2MU060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG2TU090, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3IU010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3IU020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3IU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3IU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3MU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3MU050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3TU020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3TU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG3TU060, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4IU010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4IU020, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4IU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4IU040, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4IU050, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4IU060, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4IU070, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG4MU040, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE011, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE012, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE101, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE102, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE103, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE104, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE106, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE108, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE109, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE110, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE111, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE112, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE113, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE114, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TE115, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG4TU010, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU010, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU210, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU040, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU240, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU050, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG5IU250, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XLG5IU060, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG5IU260, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU060, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU260, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU140, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XLG6IU320, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1AU000, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS2AU000, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IE072, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IE301, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IE313, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IU030, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IU040, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU070, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU200, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IU210, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IU220, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS1IU300, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS1IU310, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2AU010, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS2HU040, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS2IU040, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU100, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2IU120, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS2MU220, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU080, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU090, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU200, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU210, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU220, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU230, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU240, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU250, Label Count: 1, Content Count: 2, Objective Count: 1
# Subject: http://example.org/course/UE_XMS3IU300, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU320, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU330, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU340, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3IU360, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XMS3WU380, Label Count: 1, Content Count: 2, Objective Count: 2
# Subject: http://example.org/course/UE_XUATTENTE10, Label Count: 1, Content Count: 1, Objective Count: 1
# Subject: http://example.org/course/UE_XUATTENTE20, Label Count: 1, Content Count: 2, Objective Count: 1

# %%
#  Number of UE to align... (254 * 3 faiss * 3 LLM ~ 2229 alignements)

query_ue = """
PREFIX course: <http://example.org/course/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?UE 
WHERE {
  { select ?s (group_concat(distinct ?label) as ?labels)
              (group_concat(distinct ?content) as ?contents)
              (group_concat(distinct ?objective) as ?objectives)
    WHERE {
        # ?s rdfs:label ?label .
        # ?s course:content ?content .
        # ?s course:objective ?objective .
    } group by ?s 
  }
  BIND(CONCAT("Course Name: ", STR(?labels), 
              "Objectives: ", STR(?objectives),
              "Course content: ", STR(?contents)) AS ?UE)
}
"""

# Execute the query
results_ue = g.query(query_ue)

# Print the results
print(f"Number of results: {len(results_ue)}")
for row in results_ue:
    print(row)
# Out:
# Number of results: 209
# (rdflib.term.Literal("Course Name: Advanced image and video processing Research methodology and case study YG9U15- Machine learning for computer vision YG9U17- Perceptual computingObjectives: (résultats d'apprentissage)\nguidelines\nof the teaching unit to their work. (résultats d'apprentissage) - choose the appropriate datasets, apply necessary preprocessings\n- train, optimize and use classical machine learning tools (GMM, MLP, SVM, deeplearning)\n- evaluate the spatial relations between objects\n- understand a grammar based system to parse complex objects\n• Data preprocessing (normalization), Feature extraction\n• Classification :\n- Mixture models (GMM), Bayesienne decision\n- Neural Networks (from MLP to deep-learning), Kernel Machines (SVM), Semi-supervised\nlearning (résultats d'apprentissage) image problem via these tools\n• Manipulate the discrete geometry concepts in a real applicative environment either for medical\nimaging (image acquisition, tomography, quantizing image information) or for image analysis\n(medical, materials, ...). A large set of examples is available from the teams projects and are applied\nwith the previous concepts in real time constraints environments (résultats d'apprentissage) theoretical and practical knowledge acquired during this course in order to design and evaluate\nimage and video processing algorithms that take into account the properties of the human visual\nsystem.\n1. Visual perception: physiology and theories\n• The physics of vision and physiological basis of visual perception (retina, visual pathways, visual\ncortex)\n• Spatial vision, Color perception, Depth perception, Visual motion perception\n• Shape and object perception. Visual perception theories: Gestalt, Brunswik's probabilistic\nfunctionalism, neurophysiological approach, Gregory's theory, Gibson's theory, Marr's\ncomputationnal approachCourse content: - Structure recognition (spatial relation analysis, 1D / 2D grammar based system, CYK parsing)\n- Data set properties (size, diversity, labeling cost)\n• Applications :\n- Offline and Online Handwriting recognition\n- Visual object recognition 2. Visual Experiments and modeling\n• Fundamentals of psychophysics, visual perception experiments with humans\n• Visual attention and eytracking experiments, cognitive aspects\n3. Applications: perceptual based processing\n• Perceptual watermarking, Video and image quality assessment, Perceptual image and video\ncoding\n• 3D, stereo and autostereo applications Ethics of research • Discrete reconstruction"),)
# (rdflib.term.Literal("Course Name: Anglais pour la communication scientifique (info)Objectives: (résultats d'apprentissage)\nreplacer l’article dans son contexte et expliquer les enjeux de la recherche ou de la thématique\nabordée dans cet article.\n3. présenter son travail dans un anglais clair et phonologiquement approprié, en utilisant des outils\nde présentation adaptés et en communiquant avec un degré d’aisance et de spontanéité qui rende\npossible une interaction normale avec un locuteur natif, sans recours excessif aux notes.\n1. Développement du vocabulaire scientifique général\n2. Développement du vocabulaire scientifique de spécialité\n3. Analyse de textes scientifiques\n4. Développement de la capacité à adapter son discours à différentes situations de communication À l’issue de cet enseignement, l’étudiant-e sera capable de :\n1. répondre à des questions de compréhension sur un texte rédigé en anglais universitaire, que ce soit dans son domaine de spécialité ou dans un autre domaine, dans un esprit similaire à ce qui est proposé à l’épreuve de compréhension écrite de la certification IELTS Academic English.\n2. présenter à l’oral un texte issu de la presse scientifique générale dans son domaine de spécialité, replacer l’article dans son contexte et expliquer les enjeux de la recherche ou de la thématique abordée dans cet article.\n3. présenter son travail dans un anglais clair et phonologiquement approprié, en utilisant des outils de présentation adaptés et en communiquant avec un degré d’aisance et de spontanéité qui rende possible une interaction normale avec un locuteur natif, sans recours excessif aux notes.Course content: 1. Développement du vocabulaire scientifique général\n2. Développement du vocabulaire scientifique de spécialité\n3. Analyse de textes scientifiques\n4. Développement de la capacité à adapter son discours à différentes situations de communication scientifique\n4. Analyse de documents audio ou vidéo\n5. Pratique de l’oral en contexte\n6. Sensibilisation au système phonologique de l’anglais pour améliorer la prise de parole des étudiant-e-s scientifique\n4. Analyse de documents audio ou vidéo\n5. Pratique de l’oral en contexte\n6. Sensibilisation au système phonologique de l’anglais pour améliorer la prise de parole des\nétudiant-e-s"),)
# (rdflib.term.Literal("Course Name: Initiation à la gestion de projetObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: StageObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 1st year English S1Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: InformatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Informatique renforceeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 1st year English S2Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Algorithmique et developpementObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de donnees 1Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Fonctionnement des ordinateursObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases theoriques de l'informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Accompagnement informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 2nd year English S3Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Methodologie et insertion professionnelle S3Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage d'immersion professionnelle en entrepriseObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 2nd year English S4Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Unité Enseignement de DécouverteObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet de Recherche Biblio CMIObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: AnglaisObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes PRO alternéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie des exigencesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Comptabilité financièreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: ProfessionalisationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Gestion de ProjetObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie des exigences ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Comptabilité financière ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Gestion de Projet ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: AnglaisObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: RéseauxObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Administration des BDObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Controle de GestionObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: StageObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes PRO alterrnéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Digitalisation des organisationsObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Développement Web back-endObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Réseaux ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Administration des BD ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Contrôle de Gestion ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Digitalisation des organisations ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Dev Web back-end ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais scientifiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Engineering for Research IObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Research DiscoveryObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: MétaheuristiquesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Analyse exploratoire de donnéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Développement et exploitationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Optimisation discrète et combinatoireObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet transversalObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de comptabilitéObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Engineering for Research IIObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Summer Internship (M1 SMART)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Professionnalisation et éthiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Apprentissage automatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: CompilationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de données avancéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Modèles probabilistesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie de la décisionObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Informatique temps réel et embarquéeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingéniérie des réseauxObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: stage volontaire en informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Optimiser sous incertitudeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Programmation distribuéeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Conception pilotée par le domaineObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: MiddlewareObjectives: (résultats d'apprentissage) - Comprendre les principe de HTTP et Websocket\n- Etre capable de concevoir une API fondée sur REST\n- Etre capable de créer un web service en utilisant le framework Spring\n- Comprendre les concepts d'authentification et de sécurité\n- Comprendre les concepts de services basés composants et de micro services - Comprendre les fondements de la synchronisation liés à la concurrence\n- Comprendre les architecture n-tiers (e.g. J2E) et les technologies associées\n- Connaître les limites théoriques des applications distribuées\n- Etre capable de mettre en place une architecture client/serveur utilisant des objets distants\n- Comprendre les principe de HTTP et Websocket\n- Etre capable de concevoir une API fondée sur REST\n- Etre capable de créer un web service en utilisant le framework Spring\n- Comprendre les concepts d'authentification et de sécurité\n- Comprendre les concepts de services basés composants et de micro servicesCourse content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Gestion des données distribuées à large échelleObjectives: (résultats d'apprentissage) • To understand how big are big data and how distributed infrastructures are able to handle them\n• To understand why traditional databases cannot handle big data\n• To know online transaction processing, online analytical processing and streaming processing on big data.\n• To know representative distributed datastore for big data OLTP ie. CouchBase, Google BigTable...\n• To know how to program with Map-Reduce, resilient data structures, and stream processing ie. Hadoop, SPARK, Flink\n• To know consistent hashing, linear hashing, distributed linear hashing, sharding\n• To know multi-version concurrency control and consistency issues in large scale datastore\n• To be able to understand how current datastore are built, what they can do and what are their limitations.\n• To be able to use large scale datastore for OLTP, OLAP and stream processing.Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Deep Learning and Intensive Software Systems (EMN)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Architectures répartiesObjectives: (résultats d'apprentissage) and distributed query processing\n• To know personal information systems and small data ie. Solid\n• To know federated query processing over semantic web: FedX, Anapsid To know\n• To be able to solve data integration problems on the web • To understand the vision of the decentralized web\n• To understand data integration problems\n• To know how to build distributed data integration systems with GAV (Global as View), LAV, GLAV and distributed query processing\n• To know personal information systems and small data ie. Solid\n• To know federated query processing over semantic web: FedX, Anapsid To know\n• To be able to solve data integration problems on the webCourse content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie dirigée par les modèlesObjectives: (résultats d'apprentissage)\nlangage.\n5. Être capable de concevoir un langage spécifique au domaine.\n6. Être capable d'intégrer l'ingénierie basée sur les modèles dans le processus de développement\nlogiciel.\n7. Être capable de réaliser des transformations de modèle à modèle.\n8. Être capable de réaliser effectuer des transformations de modèle à texte (génération de code). 1. Comprendre les principes et les objectifs de l'ingénierie dirigée par sur les modèles.\n2. Comprendre les différences entre la modélisation et la méta-modélisation.\n3. Comprendre les différences entre les langages spécifiques au domaine et les langages génériques.\n4. Connaître les différences entre la syntaxe abstraite , la syntaxe concrète et la sémantique d'un langage.\n5. Être capable de concevoir un langage spécifique au domaine.\n6. Être capable d'intégrer l'ingénierie basée sur les modèles dans le processus de développement logiciel.\n7. Être capable de réaliser des transformations de modèle à modèle.\n8. Être capable de réaliser effectuer des transformations de modèle à texte (génération de code).Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal('Course Name: Gestion des logicielsObjectives: (résultats d\'apprentissage)\n- Etre capable d\'estimer les couts et durées d\'un projet (M)\n- Comprendre les outils et l\'organisation d\'un travail collaboratif (M). - Etre capable d\'appliquer les méthodes et outils pour développer un "Senior Capstone Project" t (A)\n- Etre capable d\'identifier les différentes étapes de gestion d\'un projet   (M)\n- Etre capable d\'estimer les couts et durées d\'un projet (M)\n- Comprendre les outils et l\'organisation d\'un travail collaboratif   (M).Course content: Méthodes d’enseignement'),)
# (rdflib.term.Literal("Course Name: Services de communication et systèmes distribuésObjectives: (résultats d'apprentissage) - Etre capable de développer un service dans une architecture monolithique simple\n- Etre capable d'utiliser un Domain Drived Design (DDD) pour implémenter une architecture\norientée services\n- Comprendre les paradigmes nés de l’expansion du cloud et de l’exploitation des services (e.g. - Comprendre la notion de service ainsi que ses différents paradigmes\n- Connaître les principes SOA et son implémentation modulaire via les web-services\n- Connaître les technologies relatives aux web-services (e.g. SOAP, WSDL, UDI)\n- Connaître les changements induits par la notion de service à tous les niveaux\n- Etre capable de développer un service dans une architecture monolithique simple\n- Etre capable d'utiliser un Domain Drived Design (DDD) pour implémenter une architecture orientée services\n- Comprendre les paradigmes nés de l’expansion du cloud et de l’exploitation des services (e.g. SaaS, Xaas)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: ConferencesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes de formation alternées en milieu professionnel (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Programmation mathématiqueObjectives: (résultats d'apprentissage) form of a mixed integer linear program (A)\n-To be able to detect symmetry in a problem or model, and to know how to cope with this\nphenomenon (A-M)\n- To apprehend Lagragian relaxation with effective implementation (M)\n- To discover the implementation of a column generation algorithm (I)\n-To understand the theory of Dantzig-Wolfe decomposition and to devise a column generation\napproach for various combinatorial optimization problems (M)\n-To know Branch-and-Price and the different ways to make it efficient (A)\n-To know the Benders decomposition and its relation with Dantzig-Wolfe decomposition (A)\n-To know how matheuristics work for both exact methods using approximate methods, and\nheuristics taking advantage of exact approaches (M) - To learn classical modelization techniques on various problems using specific variables (A-M)\n- To know the different strategies applicable to solve mixed integer linear programs (M)\n- To know the major techniques used in a solver to pre-process a mixed integer linear program (A)\n- To know how to implement a cutting plane algorithm based on Gomory's cuts and MIR cuts, and the limitations of these techniques (A-M)\n-To be able to compare two formulations of the same problem, and how to strenghten inequalities using lifting technique (M)\n-To know how to distinguish between valid inequalities, faces and facets, and to know the main way to prove that an inequality is a facet (M)\n-To know how to apply these techniques to graph theory or any problem that is not given under the form of a mixed integer linear program (A)\n-To be able to detect symmetry in a problem or model, and to know how to cope with this phenomenon (A-M)\n- To apprehend Lagragian relaxation with effective implementation (M)\n- To discover the implementation of a column generation algorithm (I)\n-To understand the theory of Dantzig-Wolfe decomposition and to devise a column generation approach for various combinatorial optimization problems (M)\n-To know Branch-and-Price and the different ways to make it efficient (A)\n-To know the Benders decomposition and its relation with Dantzig-Wolfe decomposition (A)\n-To know how matheuristics work for both exact methods using approximate methods, and heuristics taking advantage of exact approaches (M)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Conférences et projet intégrateurObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Complément en Anglais du Projet Intégrateur CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage Spécifique M1 CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ordonnancement et planificationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Contraintes globalesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: StageObjectives: (résultats d'apprentissage) - Synthétiser le travail effectué dans un compte rendu de manière concise, correcte, et complète.\n- Préparer des supports puis présenter oralement le travail effectué de manière dynamique et\nconvaincante. - S'intégrer dans le milieu professionel de son stage, mettre en oeuvre sa capacité d'analyse sur le sujet proposé, et être force de proposition.\n- Synthétiser le travail effectué dans un compte rendu de manière concise, correcte, et complète.\n- Préparer des supports puis présenter oralement le travail effectué de manière dynamique et convaincante.Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Période de suivi en formation par alternance (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Complément en Anglais du Stage M2 CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Etude des algorithmesObjectives: (résultats d'apprentissage) - Être capable d'écrire formellement des réductions, simples, de NP-complétude\n- Savoir choisir des propriétés à vérifier pour prouver un algorithme et pour établir sa complexité\ntemporelle\n- Savoir écrire, pour des algorithmes simples, des preuves de correction et des preuves de\ncomplexité temporelle\n- Être capable de travailler en groupe A l'issue du module, l'étudiant sera initié à\n- Savoir choisir choisir des techniques de réduction adaptées aux propriétés à préserver\n- Savoir classer des problèmes de décision\n- Savoir choisir les types vérifications à réaliser en fonction des programmes Il saura appliquer les concepts suivants:\n- Être capable d'écrire formellement des réductions, simples, de NP-complétude\n- Savoir choisir des propriétés à vérifier pour prouver un algorithme et pour établir sa complexité temporelle\n- Savoir écrire, pour des algorithmes simples, des preuves de correction et des preuves de complexité temporelle\n- Être capable de travailler en groupeCourse content: Analyse de problèmes de décision : présentation des notions de décidabilité, introduction des classes de complexité P, NP et Pspace. Présentation la Karp-réduction et de problèmes NP-Dur et NP-Complets.\nVérification de programme\n• Vérification dynamiques : aléatoire ; fonctionnelle ; structurelle\n• Vérification statique : informelle ; formelle (Hoare et Dijkstra) : correction, terminaison. Preuve et analyse en complexité temporelle de programmes itératifs et récursifs Vérification de programme\n• Vérification dynamiques : aléatoire ; fonctionnelle ; structurelle\n• Vérification statique : informelle ; formelle (Hoare et Dijkstra) : correction, terminaison."),)
# (rdflib.term.Literal("Course Name: Algorithmique et Structures de données 3Objectives: (résultats d'apprentissage) •\nimplémenter des algorithmes de parcours et de manipulation d’arbres (Application) ;\n•\nrésoudre des problèmes simples de la théorie des graphes en employant une approche gloutonne\nlorsqu’elle est appropriée (Analyse) ;\n•\ncalculer la complexité d'un algorithme en fonction des structures de données choisies (Synthèse) ;\n• choisir la structure de données la plus efficace pour la résolution d'un problème (Synthèse) ; A l’issue de cette UE, l’étudiant saura :\n•\ndéfinir une structure de données arborescente ou de type graphe en décrivant ses propriétés (Connaissance) ;\n•\nconcevoir des structures de données arborescentes ou de type graphe au moyen de structures linéaires et associatives (Analyse) ;\n•\nimplémenter des algorithmes de parcours et de manipulation d’arbres (Application) ;\n•\nrésoudre des problèmes simples de la théorie des graphes en employant une approche gloutonne lorsqu’elle est appropriée (Analyse) ;\n•\ncalculer la complexité d'un algorithme en fonction des structures de données choisies (Synthèse) ;\n• choisir la structure de données la plus efficace pour la résolution d'un problème (Synthèse) ;Course content: Programme :\nCe module présente les structures de données   arborescentes fondamentales pour la mise en place d’une algorithmique efficace, et fait une introduction à la théorie des graphes. Les compétences acquises se situent donc au niveau de la représentation de données, de leur analyse et de la mise en place d’algorithmes.\nContenu :\nStructures de données arborescentes\no    monodimensionnelles : arbres binaires, arbres AVL, classes-union etc.\no    multidimensionnelles : arbres quadtratiques (quadtrees), arbres k-d etc.\no    analyse comparative, efficacité, limites Algorithmes gloutons\no    principes, avantages et limites\no    applications Algorithmique des graphes\no    structure, propriétés, implémentations\no    pondération, arbres recouvrants\no    analyse temporelle et spatiale Structures de données arborescentes\no monodimensionnelles : arbres binaires, arbres AVL, classes-union etc."),)
# (rdflib.term.Literal("Course Name: Langage et automatesObjectives: (résultats d'apprentissage)\n- Savoir si un mot est engendré par une grammaire rationnelle, algébrique ou contextuelle\n- Connaître les propriétés d'un automate fini\n- Savoir rendre déterministe un automate fini\n- Savoir minimaliser le nombre d'états d'un automate fini déterministe\n- Savoir si un mot est accepté par un automate fini\n- Savoir transformer une grammaire rationnelle en une expression rationnelle ou en un automate\nfini et inversement A l'issue du module, l'étudiant sera initié à\n- Savoir utiliser les logiciels flex et bison Il maîtrisera les concepts:\n- Savoir raisonner sur les langages formels\n- Savoir écrire une expression rationnelle\n- Savoir résoudre un système d'équations linéaires droites\n- Savoir si un mot correspond à une expression rationnelle\n- Savoir déterminer la classe d'une grammaire formelle dans la hiérarchie de Chomsky\n- Savoir si un mot est engendré par une grammaire rationnelle, algébrique ou contextuelle\n- Connaître les propriétés d'un automate fini\n- Savoir rendre déterministe un automate fini\n- Savoir minimaliser le nombre d'états d'un automate fini déterministe\n- Savoir si un mot est accepté par un automate fini\n- Savoir transformer une grammaire rationnelle en une expression rationnelle ou en un automate fini et inversementCourse content: Automates finis et analyse lexicale : langages et opérations, langages rationnels, automates finis, automates finis déterministes. Équivalence des expressions rationnelles et des automates finis. Analyse lexicale, expressions rationnelles étendues.\nGrammaires formelles : classification, grammaires hors contexte, arbre de dérivation, ambiguïté, formes normales. Automates à pile et transducteurs finis.\nAnalyse syntaxique : analyse ascendante et descendante avec rebroussement, méthodes tabulaires, analyse sans rebroussement : grammaires de précédence, grammaires LL(k).\nTravaux Pratiques : Lex et Yacc formes normales. Automates à pile et transducteurs finis."),)
# (rdflib.term.Literal("Course Name: Réseaux et TélécomsObjectives: (résultats d'apprentissage)\n• Comprendre les mécanismes de base des protocoles de l’Internet (http, tcp, ip, arp);\n• Connaître les défis techniques et sociétaux liés aux déploiements des réseaux; A l'issue de ce cours, l'étudiant doit:\n• Acquérir une vue globale des mécanismes mis en jeu dans l’Internet (« Internet : comment ça marche ? » ) ;\n• Comprendre les mécanismes de base des protocoles de l’Internet (http, tcp, ip, arp);\n• Connaître les défis techniques et sociétaux liés aux déploiements des réseaux;Course content: Programme - Contenu de l'UE : Internet : comment ça marche.\n• Introduction : les chiffres de l'Internet, histoire et perspectives.\n• Les protocoles applicatifs (http, smtp, dns, ...)\n• Le problème du transport fiable de bout en bout. TCP.\n• Le problème du contrôle de flux et congestion. TCP.\n• Le problème de l'adressage et du routage. IP.\n• Le problème du partage du canal de transmission.\n• Les codes détecteurs et correcteurs d'erreurs.\n• Les réseaux mobile et sans fil.\n• Sécurité informatique. de l'UE : Internet : comment ça marche.\n• Introduction : les chiffres de l'Internet, histoire et perspectives.\n• Les protocoles applicatifs (http, smtp, dns, ...)\n• Le problème du transport fiable de bout en bout. TCP.\n• Le problème du contrôle de flux et congestion. TCP."),)
# (rdflib.term.Literal("Course Name: Architecture des ordinateursObjectives: (résultats d'apprentissage)\nl'implémentation des éléments logiques de base (mux/demux, registres, ...);\n• connaître les principes de la programmation dans un langage d'assemblage et savoir traduire les\nappels de fonctions et de procédures en respectant les conventions dictées par l'environnement;\n• savoir mettre en oeuvre un processeur monocycle simple en définissant les chemins de données\nde son jeu d'instructions;\n• connaître les principes sous-tendant les processeurs multicycles et les architectures pipelinées\n• connaître la notion de cache mémoire et ses différentes implémentations, et en connaître les\nimpacts sur les algorithmes. A l'issue de ce cours, l'étudiant doit:\n• connaître la représentation des informations en binaire dans les machines (entiers, réels au format IEEE 754, caractères et chaînes de caractères, instructions);\n• savoir manipuler les nombres entiers et réels dans différentes bases et passer d'une base à l'autre;\n• savoir effectuer des opérations en binaire sur les entiers et les réels;\n• savoir comparer des systèmes informatiques en fonction des indicateurs pertinents;\n• savoir analyser et synthétiser des circuits combinatoires et séquentiels et connaître l'implémentation des éléments logiques de base (mux/demux,   registres, ...);\n• connaître les principes de la programmation dans un langage d'assemblage et savoir traduire les appels de fonctions et de procédures en respectant les conventions dictées par l'environnement;\n• savoir mettre en oeuvre un processeur monocycle simple en définissant les chemins de données de son jeu d'instructions;\n• connaître les principes sous-tendant les processeurs multicycles et les architectures pipelinées\n• connaître la notion de cache mémoire et ses différentes implémentations, et en connaître les impacts sur les algorithmes.Course content: Programme   :\n* Représentation de l'information: codage des caractères, entiers, réels, instructions.\n* Métriques de performances\n* Circuits logiques combinatoires et séquentiels\n* Le processeur: présentation du jeu d'instruction d'une machine RISC et de son pipeline (aléas de données et de\ncontrôle).\n* Les mémoires: communication par bus, principe de localité, cache, virtualisation\n* Multiprocesseurs, multicœurs et GPU [optionnel, en fonction du temps disponible]\nLes travaux pratiques sont en C/C++ et en assembleur MIPS. Une partie importante du travail est laissée à l'initiative des étudiants en dehors des cours programmés. données et de\ncontrôle).\n* Les mémoires: communication par bus, principe de localité, cache, virtualisation\n* Multiprocesseurs, multicœurs et GPU [optionnel, en fonction du temps disponible]"),)
# (rdflib.term.Literal("Course Name: Systèmes dynamiquesObjectives: (résultats d'apprentissage) comportement en temps grand ; établir lien avec les équations différentielles linéaires scalaires\nd’ordre 2.\n- déterminer la nature d’un équilibre (stable asymptotiquement stable) pour un système différentiel\nautonome. Au terme de cette unité d'enseignement, l'étudiant devra :\n- appliquer le théorème de Cauchy-Lipschitz et en déduire des propriétés de la solution maximale\n- résoudre tout système différentiel linéaire homogène 2 x2 avec allure de la trajectoire et comportement en temps grand ; établir lien avec les équations différentielles linéaires scalaires d’ordre 2.\n- déterminer la nature d’un équilibre (stable asymptotiquement stable) pour un système différentiel autonome.Course content: Généralités sur les équations différentielles : problème de Cauchy ; théorème de Cauchy-Lipschitz (admis) ; lemme de Gronwall ; cas où la solution maximale est globale\nPartie I : systèmes différentiels linéaires\nRésolution pour tous les systèmes 2x2 homogènes à coefficients constants Partie II : systèmes différentiels autonomes\nA. système linéarisé au voisinage d’un équilibre\nB. Théorème de Lyapounov : définition ; cas d’un flot de gradient ; cas d’un système hamiltonien\nC. exemples classiques : modèle prédateurs/proies ; pendule. Partie II : systèmes différentiels autonomes"),)
# (rdflib.term.Literal("Course Name: Probabilités numériquesObjectives: (résultats d'apprentissage) • Au terme de cette unité d'enseignement l'étudiant devra, en matière de variables aléatoires discrètes et continues, de vecteurs Gaussiens et de convergences :\n•\nêtre capable de calculer la loi, l'espérance et la variances d'une variables aléatoires discrète, potentiellement construite à l'aide d'une famille de variables aléatoires i.i.d. de loi classique.\n•\nCalculer à l'aide de la méthode de la fonction muette,\nou bien de la fonction de répartition la loi d'une variable aléatoire absolument continue.\n•\nUtiliser la densité d'une variable aléatoire absolument continue pour calculer la probabilité d'un événement impliquant cette variable aléatoire.\n•\nAppliquer la loi forte/faible des grands nombres\npour prouver une convergence presque sure/en probabilité\n•\nAppliquer le TCL pour prouver une convergence en loi.\n•\nMettre en œuvre le Lemme de Slutsky pour obtenir, le cas échéant, la convergence en loi d'une suite de variables aléatoires construites en appliquant une fonction continue à une suite de couples de variables aléatoires dont la première coordonnée converge en loi et la seconde en probabilité vers une constante.\n•\nA l'aide de la Delta-méthode, prouver, le cas échéant, un TCL pour une suite de variables aléatoires obtenues en appliquant une fonction à une autre suite de variables aléatoires.Course content: Méthode de la fonction muette.\n• Variables aléatoires discrètes :\n•\nRappels concernant les lois classiques : uniforme, de Bernoulli, Binomiales, de Poisson, géométriques et sur les calculs d'espérances et de variances.\n•\nCouples de variables aléatoires discrètes, indépendance.\nVariables aléatoires absolument continues :\n•\nFonction de répartition et densité.\n•\nLois classiques : uniforme, exponentielle, Gaussienne,\nde Cauchy, Gamma (cas particulier de la loi du chi-deux).\n•\nCalculs d'espérance et de variance. Théorème de transfert.\n•\nMéthode de la fonction muette.\n•\nCouple de variables aléatoires à densité, indépendance. Convergences de variables aléatoires :\n•\nConvergence presque sure, en probabilité et en loi : définitions et implications.\n•\nLoi forte des grands nombres : énoncé et applications.\n•\nThéorème centrale limite : énoncé et applications.\n•\nLemme de Slutsky et Delta-méthode."),)
# (rdflib.term.Literal("Course Name: Ouverture professionnelle - InformatiqueObjectives: (résultats d'apprentissage) - étudié une structure en particulier, en lien avec son projet professionnel\n- par le biais d’un jeu de rôle, pris conscience du rôle des différents services (RH, marketing,\ncommercial,…) d’une structure dans le développement et le déploiement d’un projet\n- connaissance de ses droits et devoirs en tant que stagiaire et aura travaillé sur sa manière de\ns’intégrer et de s’adapter dans un nouveau milieu professionnel\n- connaissance de ce qu’est l’entreprenariat et des dispositifs en lien à l’université Projet Professionnel : recherche de stage et poursuite d’études A l’issue de cette UE, l’étudiant saura :\n- optimiser sa méthodologie de recherche de stage\n- décrypter une offre de stage\n- réactualiser ses compétences et remettre son CV à jour\n- le fonctionnement des réseaux sociaux professionnels et créer son profil\n- utiliser les services de l’université pour ses recherches de stage ou d’emploi. Découverte et connaissance du monde du travail\nA l’issue de cette UE, l’étudiant aura :\n- travaillé en équipe sur les différentes structures et organisations possibles rencontrées dans le monde du travail (statut juridique, services, organigramme, taille, valeurs, partenaires..)\n- étudié une structure en particulier, en lien avec son projet professionnel\n- par le biais d’un jeu de rôle, pris conscience du rôle des différents services (RH, marketing, commercial,…) d’une structure dans le développement et le déploiement d’un projet\n- connaissance de ses droits et devoirs en tant que stagiaire et aura travaillé sur sa manière de s’intégrer et de s’adapter dans un nouveau milieu professionnel\n- connaissance de ce qu’est l’entreprenariat et des dispositifs en lien à l’université Communication\nAu terme de l’UE ‘Ouverture Professionnelle’, l’étudiant connaitra :\n- les principes fondamentaux de la communication systémique et interpersonnelle, utiles pour communiquer en milieu professionnel\n- la manière d'exprimer un message clair, précis, bienveillant, à la reformulation et à l’expression d’un feedbackCourse content: 4h00 : TD 4 : Simulations d’entretiens en sous-groupes autonomes et présentation du pitch\n(évaluation).\n4h00 : TD 5 : Les différentes structures et organisations possibles dans le monde du travail / Droits\net devoirs du stagiaire.\n1h20 : TD 6 : L’après licence : en sous-groupes, argumentation de ses perspectives post-licence. L’enseignement de cette UE est réparti comme suit :\n1. Des séances de TD permettant de travailler en mode projet sur la recherche de stage et la communication orale : méthodologie, CV, lettre de motivation, utilisation du réseau professionnel LinkedIn, de l’outil CareerCenter et certains réseaux pour les scientifiques tels que Researchgate.\n2. Des séances de TD permettant de vivre et de comprendre le fonctionnement d’une structure professionnelle. Ces séances permettront également à l’étudiant de réfléchir à son positionnement en tant que stagiaire dans un environnement professionnel.\n2h40 : TD 1 : Méthodologie de recherche de stage : réflexion sur les objectifs pour ce stage, construction des différentes étapes de la recherche, décryptage d’une offre, mise à jour des compétences, du CV et personnalisation de la lettre de motivation.\n1h20 : TD 2 : Outils de recherche de stage : CareerCenter, LinkedIn : présentation et temps pour remplir son profil.\n2h40 : TD 3 : Communication orale : les fondamentaux de la communication, le non verbal, comment construire une présentation professionnelle pour se présenter à un recruteur (pitch), adopter une posture professionnelle.\n4h00 : TD 4 : Simulations d’entretiens en sous-groupes autonomes et présentation du pitch\n(évaluation).\n4h00 : TD 5 : Les différentes structures et organisations possibles dans le monde du travail / Droits et devoirs du stagiaire.\n1h20 : TD 6 : L’après licence : en sous-groupes, argumentation de ses perspect ...
# (rdflib.term.Literal("Course Name: Anglais Professionnel InformatiqueObjectives: (résultats d'apprentissage) 3. faire une présentation orale s’appuyant sur le travail de groupe préparé dans le rapport écrit, en\ns’exprimant dans un anglais clair et phonologiquement approprié et en communiquant avec un\ndegré d’aisance et de spontanéité qui rende possible une interaction normale avec un locuteur natif,\nsans recours excessif aux notes\n4. utiliser des outils de présentation adaptés à la situation de communication\n5. répondre à des questions de compréhension sur des documents audio authentiques\n1. Développement du vocabulaire utilisé en anglais professionnel (vocabulaire susceptible d’être\nutilisé dans les tests TOEIC)\n2. Discussion des spécificités des CV aux États-Unis et en Grande-Bretagne\n3. Contenu d’une lettre de motivation À l’issue de cet enseignement, l’étudiant-e sera capable de :\n1. réaliser un rapport dans le cadre d’un projet de groupe impliquant une mise en situation dans un contexte professionnel simulé\n2. rédiger un texte dans un anglais clair et grammaticalement approprié au contexte, dans le cadre d’un projet de groupe\n3. faire une présentation orale s’appuyant sur le travail de groupe préparé dans le rapport écrit, en s’exprimant dans un anglais clair et phonologiquement approprié et en communiquant avec un  degré d’aisance et de spontanéité qui rende possible une interaction normale avec un locuteur natif, sans recours excessif aux notes\n4. utiliser des outils de présentation adaptés à la situation de communication\n5. répondre à des questions de compréhension sur des documents audio authentiquesCourse content: 1. Développement du vocabulaire utilisé en anglais professionnel (vocabulaire susceptible d’être utilisé dans les tests TOEIC)\n2. Discussion des spécificités des CV aux États-Unis et en Grande-Bretagne\n3. Contenu d’une lettre de motivation\n4. Déroulement d’un entretien d’embauche\n5. Vocabulaire utilisé lors des communications téléphoniques\n6. Pratique de l’oral en contexte\n7. Sensibilisation au système phonologique de l’anglais pour améliorer la prise de parole des étudiant-e-s d’une lettre de motivation"),)
# (rdflib.term.Literal("Course Name: Projet intégrateur CMIObjectives: (résultats d'apprentissage)Course content: L'objectif du projet intégrateur est double :\n•\n‐   comme son nom l'indique, un projet intégrateur doit conduire l'étudiant à utiliser l'ensemble des connaissances qu'il a acquises dans les diverses unités d'enseignement. Ce projet montre la complémentarité des disciplines, la cohérence du cursus et contribue à développer une vision systémique de la spécialité à l’étudiant ;\n•\n‐   apprendre à gérer un projet, surmonter les contraintes (organisation, délais, satisfaction du\n«client»), s'attaquer à du concret et travailler en équipe. complémentarité des disciplines, la cohérence du cursus et contribue à développer une vision\nsystémique de la spécialité à l’étudiant ;\n•\n‐ apprendre à gérer un projet, surmonter les contraintes (organisation, délais, satisfaction du\n«client»), s'attaquer à du concret et travailler en équipe."),)
# ...
# (rdflib.term.Literal("Course Name: Modélisation des languesObjectives: (résultats d'apprentissage)\n• Architectures et modèles (statique, contextuel, mécanisme d'attention, transformer, encodeur et\ngénératif, multimodalité, compression)\n• Apprentissage (pré-entrainement, entraînement, renforcement, fine-tuning, continuous learning,Course content: adversarial, adaptation au domaine, Parameter-Efficient Fine-Tuning)\n• Représentation profonde des mots, des phrases, des séquences longues\n• Injection de connaissances, augmentation de données\n• Analyse et interprétabilité (biais) • Architectures et modèles (statique, contextuel, mécanisme d'attention, transformer, encodeur et génératif, multimodalité, compression)\n• Apprentissage (pré-entrainement, entraînement, renforcement, fine-tuning, continuous learning, adversarial, adaptation au domaine, Parameter-Efficient Fine-Tuning)\n• Représentation profonde des mots, des phrases, des séquences longues\n• Injection de connaissances, augmentation de données\n• Analyse et interprétabilité (biais)"),)
# (rdflib.term.Literal("Course Name: Traitement automatique des languesObjectives: (résultats d'apprentissage)\n• Paradigmes de résolution des problématiques de TAL\n• Applications/tâches d'analyse (extraction d'information e.g. NE/relations, résolution de la co-\nréférence, classification d'énoncés, alignement)\n• Applications/tâches génératives (résumé, question/réponse, traduction, génération de code, agentCourse content: conversationnel/chatbot) - protocole, données, approches état de l'art et évaluation\n• Recherche d'information\n• Domaine de spécialités : problématiques et approches (médical et santé, légal, scientifique,\néducation)\n• Exploitation de GPU/supercalcultateur • Paradigmes de résolution des problématiques de TAL\n• Applications/tâches d'analyse (extraction d'information e.g. NE/relations, résolution de la co- référence, classification d'énoncés, alignement)\n• Applications/tâches génératives (résumé, question/réponse, traduction, génération de code, agent conversationnel/chatbot) - protocole, données, approches état de l'art et évaluation\n• Recherche d'information\n• Domaine de spécialités : problématiques et approches (médical et santé, légal, scientifique, éducation)\n• Exploitation de GPU/supercalcultateur"),)
# (rdflib.term.Literal("Course Name: Ressources linguistiquesObjectives: (résultats d'apprentissage)\n• Construction de corpus (typologie, constitution, méta-données, codage, corpus et jeux de données\nde références...) et de lexiques\n• Annotation (procédure, guide d'annotation, outils, mesure d'accord)Course content: • Construction de corpus (typologie, constitution, méta-données, codage, corpus et jeux de données de références...) et de lexiques\n• Annotation (procédure, guide d'annotation, outils, mesure d'accord)\n• Valorisation (diffusion de jeux de données/modèles, licence)\n• Evaluation, métriques, campagnes\n• Prompting for LLM application development\n• Retrieval Augmented Generation (RAG) • Valorisation (diffusion de jeux de données/modèles, licence)\n• Evaluation, métriques, campagnes\n• Prompting for LLM application development\n• Retrieval Augmented Generation (RAG)"),)
# (rdflib.term.Literal("Course Name: Développement logiciel et IA dans les entreprisesObjectives: (résultats d'apprentissage)\n* Agilité et gestion de projetsCourse content: * Agilité et gestion de projets\n* Processus en amont et aval de la construction de modèles (recueil besoins, trajectoire client, acculturation, chiffrage, planification, industrialisation, packaging, performance) * Processus en amont et aval de la construction de modèles (recueil besoins, trajectoire client,\nacculturation, chiffrage, planification, industrialisation, packaging, performance)"),)
# (rdflib.term.Literal('Course Name: Algorithmique du texte et inférence grammaticaleObjectives: (résultats d\'apprentissage)Course content: Contenu de la partie "Algorithmique du Texte":\n1. Automate déterministe de reconnaissance du motif\n2. Arbre des Suffixes\n3. Tableau des Suffixes\n4. Transformée de Burrows-Wheeler et FM-index Partie "Algorithmique du Texte"\nConnaissance et acquisition des principales techniques de recherche de motifs dans les textes de grande taille, avec pré-traitement sur le texte et/ou le motif\nConnaissance et acquisition des algorithmes associés et de leur complexité.\nComparaison des avantages/inconvénients des techniques présentées, en fonction du contexte d\'utilisation.\nContenu de la partie "Algorithmique du Texte":\n1. Automate déterministe de reconnaissance du motif\n2. Arbre des Suffixes\n3. Tableau des Suffixes\n4. Transformée de Burrows-Wheeler et FM-index\nCes techniques seront illustrées d\'exemples d\'applications au traitement des séquences d\'ADN.'),)
# (rdflib.term.Literal('Course Name: Communication scientifiqueObjectives: (résultats d\'apprentissage)\n* Réalisation d\'étude bibliographique et de présentation d\'articles dans le domaine\n* Participation à séminaires "Petit Séminaires ATAL"Course content: * Construction de poster, rédaction en latex, gestion bibliographique * Réalisation d\'étude bibliographique et de présentation d\'articles dans le domaine\n* Participation à séminaires "Petit Séminaires ATAL"\n* Construction de poster, rédaction en latex, gestion bibliographique'),)
# (rdflib.term.Literal("Course Name: Optimisation multi-objectifObjectives: (résultats d'apprentissage)\nproblems (M)\n- To be able to apply the e-constraint algorithm with adaptive step to solve a bi-objective\ncombinatorial problem (A)\n- To be able to apply the weighted sum scalarization to compute a complete set of extreme\nsupported solution of a bi-objective combinatorial optimization problem (A)\n- To be able to define and update the search area of a bi-objective combinatorial optimization\nproblem (Phase 2 of the two phase method) (A)\n- To know the main strategies (variable fixing, ranking, branch and bound) to explore the search\narea (A)\n- To know the notion of bound sets (M)\n- To be able to apply a branch and bound algorithm to solve a bi-objective combinatorial\noptimization problem (A)\n- To be able to apply a dynamic programming algorithm for multi-objective combinatorial\noptimization problem, application to the shortest path problem (A) - To know the notion of feasible set, outcome set, solution, point, (weakly) efficient, (weakly) nondominated point, lexicographically optimal solution (M)\n- To know the ideal point and the nadir point, the way to compute these points and the difficulty in their computation (M)\n- To know the main scalarization methods (weighted sum, e-constraint, weighted tchebychev method) and their properties (A)\n- To know the geometrical properties of the feasible set and the outcome set of a MOLP (M)\n- To know the geometrical and topological properties of the efficient set and the nondominated set of a MOLP (M)\n- To be able to apply the parametric simplex algorithm to solve a bi-objective linear programme (A)\n- To know the topological property of the feasible, outcome, efficient, nondominated sets of a Multi- objective Combinatorial Optimization (MOCO) problem (M)\n- To know the classification of efficient solutions and nondominated points, and the notion of complete set (M)\n- To know results about connectedness and non-connectedness of efficient solutions of MOCO problems (M)\n- To be able to apply the e-constraint algorithm with adaptive step to solve a bi-objective combinatorial problem (A)\n- To be able to apply the weighted sum scalarization to compute a complete set of extreme supported solution of a bi-objective combinatorial optimization problem (A)\n- To be able to define and update the search area of a bi-objective combinatorial optimization problem (Phase 2 of the two phase method) (A)\n- To know the main strategies (variable fixing, ranking, branch and bound) to explore the search area (A)\n- To know the notion of bound sets (M)\n- To be able to apply a branch and bound algorithm to solve a bi-objective combinatorial optimization problem (A)\n- To be able to apply a dynamic programming algorithm for multi-objective combinatorial optimization problem, application to the shortest path problem (A)Course content: * Multi-objective combinatorial optimization - main definitions and properties\n* Multi-objective combinatorial optimization - main solution methods\n* Multi-objective shortest path problem This course is composed of 5 chapters.\n* Introduction to multi-objective optimization\n* Multi-objective linear programming\n* Multi-objective combinatorial optimization - main definitions and properties\n* Multi-objective combinatorial optimization - main solution methods\n* Multi-objective shortest path problem"),)
# (rdflib.term.Literal("Course Name: Optimisation globaleObjectives: (résultats d'apprentissage) • Connaître les stratégies de recherche usuelles\n• Mettre en oeuvre un solveur de problèmes d'optimisation non linéaires • Comprendre les méthodes de calcul par intervalles et le calcul automatique de bornes d'erreurs\n• Savoir linéariser un problème non linéaire\n• Connaître les stratégies de recherche usuelles\n• Mettre en oeuvre un solveur de problèmes d'optimisation non linéairesCourse content: Ce cours présente des algorithmes de recherche déterministes pour résoudre des problèmes de satisfaction et d'optimisation non linéaires de manière rigoureuse.\n• Algorithme branch-and-bound\n• Arithmétique par intervalles\n• Techniques de réduction\n• Techniques de linéarisation\n• Certification des calculs numériques • Arithmétique par intervalles\n• Techniques de réduction\n• Techniques de linéarisation\n• Certification des calculs numériques\n• Classe inversée"),)
# (rdflib.term.Literal("Course Name: Algorithmique du génomeObjectives: (résultats d'apprentissage) Comprendre, reproduire et adapter les algorithmes de recherche de motifs Comprendre les enjeux de la génomique comparative et les défis algorithmiques associés Comprendre, reproduire et adapter les algorithmes de recherche de motifs\nComprendre, reproduire et adapter les algorithmes d'alignement de séquencesCourse content: Alignement de séquences Introduction à l'algorithmique du génome\nRecherche exacte ou approchée de motifs avec ou sans indexation Alignement de séquences\nApplications"),)
# (rdflib.term.Literal("Course Name: Optimisation en robotiqueObjectives: (résultats d'apprentissage)\noptimization problems (Analysis) ;\n* model a variety of robotic problems as numerical constrained optimization problems and solve\nthem using an appropriate method (Synthesis) ; * understand the kinematic models of various serial and parallel robotic manipulators (Understanding) ;\n* describe a variety of optimization problems in robotics and identify the corresponding classes of optimization problems (Analysis) ;\n* model a variety of robotic problems as numerical constrained optimization problems and solve them using an appropriate method (Synthesis) ;Course content: Optimization in Robotics presents a number of optimization problems arising in robotics and demonstrates how the optimization techniques learnt throughout the Master allow solving them. demonstrates how the optimization techniques learnt throughout the Master allow solving them."),)
# (rdflib.term.Literal("Course Name: Solveurs multi-objectifsObjectives: (résultats d'apprentissage)\nmétaheuristique multiobjectif.\n• Appréhender et conduire des cas d'étude. • Comprendre, mettre en oeuvre, contributer aux fonctionnalités d'un solveur multi-objectif.\n• Apporter une réponse algorithmique et une solution logicielle mettant en oeuvre une métaheuristique multiobjectif.\n• Appréhender et conduire des cas d'étude.Course content: Optimisation multi-objectif (MOO)\n• Rappels\n• Des solveurs multi-objectif basés sur des algorithmes complets\n• Etude de cas\nMétaheuristiques multi-objectif (MOMH)\n• Définition\n• Dates et contributions remarquables\n• Lignée des algorithmes évolutionnaires multi-objectif (EMO)\n• Non-dominated Sorting Genetic Algorithm 2 : NSGA-II\nQuestions sensibles\n• Concernant le maintien des points potentiellement non-dominés\n• Concernant une recherche locale multi-objectif\n• Concernant la mesure de la qualité d’une approximation\nOrientations\n• Des approches de résolution hybrides\n• Des solveurs multi-objectif basés sur les métaheuristiques\nProjet • Non-dominated Sorting Genetic Algorithm 2 : NSGA-II"),)
# (rdflib.term.Literal("Course Name: Transport et logistiqueObjectives: (résultats d'apprentissage) + Heuristics for vehicle routing problems M\n+ Meta heuristics for vehicle routing problems A\n+ Solving vehicle routing problems with time windows A\n+ Advanced exact methods for facility location and vehicle routing (Branch and cut, Lagrangean\nrelaxation, column generation) I. + Information systems and softwares in transport optimization I.\n+ Modeling classical facility location and vehicle routing problems E\n+ Modeling advanced facility location, network design and vehicle routing problems M\n+ Heuristic solving of facility location problems I\n+ Heuristics for vehicle routing problems M\n+ Meta heuristics for vehicle routing problems A\n+ Solving vehicle routing problems with time windows A\n+ Advanced exact methods for facility location and vehicle routing (Branch and cut, Lagrangean relaxation, column generation) I.Course content: - Model the core problems and their simple extensions\n- Design some exact and heuritic solving methods for these optimization problems At the end of this course, the student will be able to:\n- Identify the main optimization problems that arise in the field of transportation and logistics\n- Model the core problems and their simple extensions\n- Design some exact and heuritic solving methods for these optimization problems"),)
# (rdflib.term.Literal("Course Name: Research methodologyObjectives: (résultats d'apprentissage)Course content: Then we focus on the content of scientific documents, how to read them, and how to write scientific\nmaterial, before addressing the topic of how to search for scientific material with the tools at hand\nand organize them in a bibliography."),)
# (rdflib.term.Literal("Course Name: Deep learningObjectives: (résultats d'apprentissage)\n• Cours : MLP, CNN, RNNCourse content: • Cours : MLP, CNN, RNN\n• TD : Nombre de poids, tailles des CNN, étude d'architechtures classiques, CTC\n• TP : IRIS, MINST, Seq • TD : Nombre de poids, tailles des CNN, étude d'architechtures classiques, CTC\n• TP : IRIS, MINST, Seq"),)

# %%
#  Number of UE to align... (254 * 3 faiss * 3 LLM ~ 2229 alignements)

query_ue = """
PREFIX course: <http://example.org/course/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT ?UE 
WHERE {
  { select ?s (group_concat(distinct ?label) as ?labels)
              (group_concat(distinct ?content) as ?contents)
              (group_concat(distinct ?objective) as ?objectives)
    WHERE {
        # ?s rdfs:label ?label .
        # ?s course:content ?content .
        # ?s course:objective ?objective .
    } group by ?s 
  }
  BIND(CONCAT("Course Name: ", STR(?labels), 
              "Objectives: ", STR(?objectives),
              "Course content: ", STR(?contents)) AS ?UE)
   FILTER(STRLEN(STR(?UE)) < 200)
}
"""

# Execute the query
results_ue = g.query(query_ue)

# Print the results
print(f"Number of results: {len(results_ue)}")
for row in results_ue:
    print(row)
# Out:
# Number of results: 81
# (rdflib.term.Literal("Course Name: Initiation à la gestion de projetObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: StageObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 1st year English S1Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: InformatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Informatique renforceeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 1st year English S2Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Algorithmique et developpementObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de donnees 1Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Fonctionnement des ordinateursObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases theoriques de l'informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Accompagnement informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 2nd year English S3Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Methodologie et insertion professionnelle S3Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage d'immersion professionnelle en entrepriseObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: 2nd year English S4Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Unité Enseignement de DécouverteObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet de Recherche Biblio CMIObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: AnglaisObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes PRO alternéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie des exigencesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Comptabilité financièreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: ProfessionalisationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Gestion de ProjetObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie des exigences ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Comptabilité financière ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Gestion de Projet ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: AnglaisObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: RéseauxObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Administration des BDObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Controle de GestionObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: StageObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes PRO alterrnéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Digitalisation des organisationsObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Développement Web back-endObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Réseaux ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Administration des BD ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Contrôle de Gestion ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Digitalisation des organisations ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Dev Web back-end ALTObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage libreObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Anglais scientifiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Engineering for Research IObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Research DiscoveryObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: MétaheuristiquesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Analyse exploratoire de donnéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Développement et exploitationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Optimisation discrète et combinatoireObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet transversalObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de comptabilitéObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Engineering for Research IIObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Summer Internship (M1 SMART)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Professionnalisation et éthiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Apprentissage automatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: CompilationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Bases de données avancéesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Modèles probabilistesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingénierie de la décisionObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Informatique temps réel et embarquéeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ingéniérie des réseauxObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: stage volontaire en informatiqueObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Optimiser sous incertitudeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Programmation distribuéeObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Conception pilotée par le domaineObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Deep Learning and Intensive Software Systems (EMN)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: ConferencesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Projet (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Périodes de formation alternées en milieu professionnel (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Conférences et projet intégrateurObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Complément en Anglais du Projet Intégrateur CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Stage Spécifique M1 CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Ordonnancement et planificationObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Contraintes globalesObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Période de suivi en formation par alternance (M2 ATAL)Objectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
# (rdflib.term.Literal("Course Name: Complément en Anglais du Stage M2 CMI OPTIMObjectives: (résultats d'apprentissage)Course content: Méthodes d’enseignement"),)
